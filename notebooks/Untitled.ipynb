# %%
import numpy as np
import os
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from xgboost import XGBClassifier

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv(
    "../data/data_scientist_case.csv",
    low_memory=False,
    thousands=",",
    parse_dates=[
        "segment_datetime",
        "published_date",
        "signup_date",
    ],
    dtype={"trip_id": str, "segment_id": str}
)

df = df.sort_values(by=["trip_id", "segment_id"])
df = df.set_index(["trip_id", "segment_id"])

df["from"] = list(zip(df["from_lat"], df["from_lon"]))
df["to"] = list(zip(df["to_lat"], df["to_lon"]))

df.drop(["from_lat", "from_lon", "to_lat", "to_lon"], axis=1, inplace=True)

df
# Out:
#                          driver_id    segment_datetime published_date  \
# trip_id     segment_id
# 101,237,714 578,145,698    8370779 2015-05-03 10:00:08     2015-02-19
#             578,145,704    8370779 2015-05-03 10:00:08     2015-02-19
#             578,145,710    8370779 2015-05-03 10:00:08     2015-02-19
#             578,145,716    8370779 2015-05-03 10:00:08     2015-02-19
#             578,145,722    8370779 2015-05-03 10:00:08     2015-02-19
# ...                            ...                 ...            ...
# 81,503,790  483,346,561    3899249 2015-05-09 13:20:00     2015-01-13
#             483,346,567    3899249 2015-05-09 13:20:00     2015-01-13
#             483,346,573    3899249 2015-05-09 14:25:00     2015-01-13
#             483,346,579    3899249 2015-05-09 14:25:00     2015-01-13
#             483,346,585    3899249 2015-05-09 16:15:00     2015-01-13
#
#                         signup_date fixed_signup_country  is_main_segment  \
# trip_id     segment_id
# 101,237,714 578,145,698  2013-08-17                  FR             False
#             578,145,704  2013-08-17                  FR             False
#             578,145,710  2013-08-17                  FR             False
#             578,145,716  2013-08-17                  FR             False
#             578,145,722  2013-08-17                  FR             False
# ...                             ...                  ...              ...
# 81,503,790  483,346,561  2012-06-17                  FR             False
#             483,346,567  2012-06-17                  FR             False
#             483,346,573  2012-06-17                  FR             False
#             483,346,579  2012-06-17                  FR             False
#             483,346,585  2012-06-17                  FR             False
#
#                          unit_seat_price_eur  seat_offered_count  \
# trip_id     segment_id
# 101,237,714 578,145,698                 6.60                   1
#             578,145,704                10.56                   1
#             578,145,710                18.48                   1
#             578,145,716                31.68                   1
#             578,145,722                44.88                   1
# ...                                      ...                 ...
# 81,503,790  483,346,561                27.72                   2
#             483,346,567                44.88                   2
#             483,346,573                17.16                   2
#             483,346,579                34.32                   2
#             483,346,585                17.16                   2
#
#                          seat_left_count  confirmed_seat_count  \
# trip_id     segment_id
# 101,237,714 578,145,698                1                     0
#             578,145,704                1                     0
#             578,145,710                1                     0
#             578,145,716                0                     0
#             578,145,722                0                     0
# ...                                  ...                   ...
# 81,503,790  483,346,561                0                     0
#             483,346,567                0                     0
#             483,346,573                0                     0
#             483,346,579                0                     0
#             483,346,585                1                     0
#
#                          segment_distance_km  is_comfort  is_auto_accept_mode  \
# trip_id     segment_id
# 101,237,714 578,145,698                   93       False                False
#             578,145,704                  153       False                False
#             578,145,710                  268       False                False
#             578,145,716                  474       False                False
#             578,145,722                  719       False                False
# ...                                      ...         ...                  ...
# 81,503,790  483,346,561                  295       False                False
#             483,346,567                  489       False                False
#             483,346,573                  195       False                False
#             483,346,579                  389       False                False
#             483,346,585                  195       False                False
#
#                          publication_site_id                from  \
# trip_id     segment_id
# 101,237,714 578,145,698                 5000  (42.5462, 3.02291)
#             578,145,704                 5000  (42.5462, 3.02291)
#             578,145,710                 5000  (42.5462, 3.02291)
#             578,145,716                 5000  (42.5462, 3.02291)
#             578,145,722                 5000  (42.5462, 3.02291)
# ...                                      ...                 ...
# 81,503,790  483,346,561                 1000  (44.9334, 4.89236)
#             483,346,567                 1000  (44.9334, 4.89236)
#             483,346,573                 1000   (45.7366, 4.8163)
#             483,346,579                 1000   (45.7366, 4.8163)
#             483,346,585                 1000   (47.322, 5.04148)
#
#                                           to
# trip_id     segment_id
# 101,237,714 578,145,698   (43.1843, 3.00308)
#             578,145,704   (43.2122, 2.35366)
#             578,145,710   (42.6887, 2.89483)
#             578,145,716   (43.6047, 1.44421)
#             578,145,722  (44.8378, -0.57918)
# ...                                      ...
# 81,503,790  483,346,561    (47.322, 5.04148)
#             483,346,567   (48.1724, 6.44959)
#             483,346,573    (47.322, 5.04148)
#             483,346,579   (48.1724, 6.44959)
#             483,346,585   (48.1724, 6.44959)
#
# [3379778 rows x 16 columns]

# %% [markdown]
# ### Segments
#
# If a driver is travelling from Paris to Toulouse with a stopover in Tours and a stopover in Limoge, there will be 6 segments:
#
# * Paris>Tours (direct)
# * Tours>Limoge (direct)
# * Limoge>Toulouse (direct)
# * Paris>Limoge (indirect)
# * Paris>Toulouse (indirect)
# * Tours>Toulouse (indirect)
#
# A segment is either a direct trip between two locations or an indirect trip composed of constinuent segments. I suspect that whether a segment is direct or indirect would be a good predictor of success. The number of constituent segments will likely also play a role, as well as the duration of stops.

# %%
df.loc["101,237,714"]
# Out:
#              driver_id    segment_datetime published_date signup_date  \
# segment_id
# 578,145,698    8370779 2015-05-03 10:00:08     2015-02-19  2013-08-17
# 578,145,704    8370779 2015-05-03 10:00:08     2015-02-19  2013-08-17
# 578,145,710    8370779 2015-05-03 10:00:08     2015-02-19  2013-08-17
# 578,145,716    8370779 2015-05-03 10:00:08     2015-02-19  2013-08-17
# 578,145,722    8370779 2015-05-03 10:00:08     2015-02-19  2013-08-17
# 578,145,728    8370779 2015-05-03 10:00:08     2015-02-19  2013-08-17
# 578,145,734    8370779 2015-05-03 10:00:08     2015-02-19  2013-08-17
# 578,145,740    8370779 2015-05-03 11:00:08     2015-02-19  2013-08-17
# 578,145,746    8370779 2015-05-03 11:00:08     2015-02-19  2013-08-17
# 578,145,752    8370779 2015-05-03 11:00:08     2015-02-19  2013-08-17
# 578,145,758    8370779 2015-05-03 11:00:08     2015-02-19  2013-08-17
# 578,145,764    8370779 2015-05-03 11:00:08     2015-02-19  2013-08-17
# 578,145,770    8370779 2015-05-03 11:00:08     2015-02-19  2013-08-17
# 578,145,776    8370779 2015-05-03 11:40:08     2015-02-19  2013-08-17
# 578,145,782    8370779 2015-05-03 11:40:08     2015-02-19  2013-08-17
#              segment_distance_km  is_comfort  is_auto_accept_mode  \
# segment_id
# 578,145,698                   93       False                False
# 578,145,704                  153       False                False
# 578,145,710                  268       False                False
# 578,145,716                  474       False                False
# 578,145,722                  719       False                False
# 578,145,728                  845       False                False
# 578,145,734                  963       False                False
# 578,145,740                   60       False                False
# 578,145,746                  174       False                False
# 578,145,752                  381       False                False
# 578,145,758                  626       False                False
# 578,145,764                  752       False                False
# 578,145,770                  870       False                False
# 578,145,776                  114       False                False
# 578,145,782                  321       False                False
# 578,145,788                  566       False                False
# 578,145,794                  692       False                False
# 578,145,800                  810       False                False
# 578,145,806                  207       False                False
# 578,145,812                  452       False                False
# 578,145,818                  578       False                False
# 578,145,824                  695       False                False
# 578,145,830                  245       False                False
# 578,145,836                  371       False                False
# 578,145,842                  489       False                False
# 578,145,848                  126       False                False
# 578,145,854                  244       False                False
# 578,145,860                  118       False                False
#
#              publication_site_id                 from                   to
# segment_id
# 578,145,698                 5000   (42.5462, 3.02291)   (43.1843, 3.00308)
# 578,145,704                 5000   (42.5462, 3.02291)   (43.2122, 2.35366)
# 578,145,710                 5000   (42.5462, 3.02291)   (42.6887, 2.89483)
# 578,145,716                 5000   (42.5462, 3.02291)   (43.6047, 1.44421)
# 578,145,722                 5000   (42.5462, 3.02291)  (44.8378, -0.57918)
# 578,145,728                 5000   (42.5462, 3.02291)  (45.6484, 0.156237)
# 578,145,734                 5000   (42.5462, 3.02291)  (46.5802, 0.340375)
# 578,145,740                 5000   (43.1843, 3.00308)   (43.2122, 2.35366)
# 578,145,746                 5000   (43.1843, 3.00308)   (42.6887, 2.89483)
# 578,145,752                 5000   (43.1843, 3.00308)   (43.6047, 1.44421)
# 578,145,758                 5000   (43.1843, 3.00308)  (44.8378, -0.57918)
# 578,145,764                 5000   (43.1843, 3.00308)  (45.6484, 0.156237)
# 578,145,770                 5000   (43.1843, 3.00308)  (46.5802, 0.340375)
# 578,145,776                 5000   (43.2122, 2.35366)   (42.6887, 2.89483)
# 578,145,782                 5000   (43.2122, 2.35366)   (43.6047, 1.44421)
# 578,145,788                 5000   (43.2122, 2.35366)  (44.8378, -0.57918)
# 578,145,794                 5000   (43.2122, 2.35366)  (45.6484, 0.156237)
# 578,145,800                 5000   (43.2122, 2.35366)  (46.5802, 0.340375)
# 578,145,806                 5000   (42.6887, 2.89483)   (43.6047, 1.44421)
# 578,145,812                 5000   (42.6887, 2.89483)  (44.8378, -0.57918)
# 578,145,818                 5000   (42.6887, 2.89483)  (45.6484, 0.156237)
# 578,145,824                 5000   (42.6887, 2.89483)  (46.5802, 0.340375)
# 578,145,830                 5000   (43.6047, 1.44421)  (44.8378, -0.57918)
# 578,145,836                 5000   (43.6047, 1.44421)  (45.6484, 0.156237)
# 578,145,842                 5000   (43.6047, 1.44421)  (46.5802, 0.340375)
# 578,145,848                 5000  (44.8378, -0.57918)  (45.6484, 0.156237)
# 578,145,854                 5000  (44.8378, -0.57918)  (46.5802, 0.340375)
# 578,145,860                 5000  (45.6484, 0.156237)  (46.5802, 0.340375)

# %%
from collections import defaultdict
from itertools import tee

from time import perf_counter


def compute_segment_features(trip_id):
    t1 = perf_counter()
    trip_data = df.loc[trip_id]

    dic = defaultdict(list)
    point_pair_to_segment = {}

    points = set(trip_data["from"])
    points.add(trip_data.iloc[-1]["to"])

    for segment_id, row in trip_data.iterrows():
        point_pair_to_segment[row["from"] + row["to"]] = segment_id
        dic[row["from"]].append(row["to"])

    time_first_for = perf_counter() - t1

    t1 = perf_counter()
    dic = {k: len(dic[k]) for k in points}
    sorted_locations = sorted(list(points), key=lambda x: dic[x], reverse=True)
    time_sorting = perf_counter() - t1

    t1 = perf_counter()
    seg_to_seg = defaultdict(list)
    for i in range(len(sorted_locations)):
        cur_segments = []
        for j in range(i + 1, len(sorted_locations)):
            cur_segments.append(point_pair_to_segment[(sorted_locations[j-1] + sorted_locations[j])])
            seg_to_seg[point_pair_to_segment[(sorted_locations[i] + sorted_locations[j])]] = [x for x in cur_segments]

    time_second_for = perf_counter() - t1
    
    t1 = perf_counter()
    sorted_core_segments = []
    for i in range(len(sorted_locations) - 1):
        sorted_core_segments.append(point_pair_to_segment[sorted_locations[i] + sorted_locations[i + 1]])
    time_third_for = perf_counter() - t1

    t1 = perf_counter()
    segment_durations = {}
    for i in range(len(sorted_core_segments) - 1):
        s1 = sorted_core_segments[i]
        s2 = sorted_core_segments[i + 1]
        duration = trip_data.loc[s2, "segment_datetime"] - trip_data.loc[s1, "segment_datetime"]
        duration = duration.seconds / 3600
        if duration != 0:
            segment_durations[s1] = duration
        else:
            segment_durations[s1] = None

    time_fourth_for = perf_counter() - t1

    t1 = perf_counter()
    for segment in trip_data.index:
        if segment not in segment_durations:
            subsegs = seg_to_seg[segment]
            s = 0
            all_known = True
            for seg in subsegs:
                if seg in segment_durations and segment_durations[seg] != None:
                    s += segment_durations[seg]
                else:
                    all_known = False
                    break
            if all_known:
                segment_durations[segment] = s
    time_fifth_for = perf_counter() - t1

    t1 = perf_counter()
    segment_speeds = {}
    for segment in segment_durations:
        duration = segment_durations[segment]
        if duration != None:
            segment_speeds[segment] = trip_data.loc[segment, "segment_distance_km"] / segment_durations[segment]
        else:
            segment_speeds[segment] = None
    time_sixth_for = perf_counter() - t1
    
    t1 = perf_counter()
    segment_lengths = {}
    for segment in seg_to_seg:
        segment_lengths[segment] = len(seg_to_seg[segment])
    time_seventh_for = perf_counter() - t1

    t1 = perf_counter()
    res = {}
    for segment in segment_lengths:
        res[segment] = {}
        res[segment]["length"] = segment_lengths[segment]
        res[segment]["duration"] = segment_durations.get(segment)
        res[segment]["speed"] = segment_speeds.get(segment)
    time_eighth_for = perf_counter() - t1

    return res, time_first_for, time_sorting, time_second_for, time_third_for, time_fourth_for, time_fifth_for, time_sixth_for, time_seventh_for, time_eighth_for

# %%
t1s = 0
t2s = 0
t3s = 0
t4s = 0
t5s = 0
t6s = 0
t7s = 0
t8s = 0
t9s = 0

for i in range(100):
    features, t1, t2, t3, t4, t5, t6, t7, t8, t9 = compute_segment_features("101,237,714")
    t1s += t1
    t2s += t2
    t3s += t3
    t4s += t4
    t5s += t5
    t6s += t6
    t7s += t7
    t8s += t8
    t9s += t9

print(t1s / 100)
print(t2s / 100)
print(t3s / 100)
print(t4s / 100)
print(t5s / 100)
print(t6s / 100)
print(t7s / 100)
print(t8s / 100)
print(t9s / 100)
# Out:
# 0.008199907109810738
# 9.34060983126983e-06
# 3.3017789683071896e-05
# 2.869750460376963e-06
# 0.000409587049507536
# 2.2214271157281474e-05
# 0.0003632804600056261
# 4.976620402885601e-06
# 1.2944671470904723e-05

# %%
from tqdm import tqdm
from multiprocessing import Pool

pool = Pool(10)

tt = 0
for i in tqdm(range(100)):
    t1 = perf_counter()
    segment_features = pool.map(compute_segment_features, df.index.levels[0][:100])
    t = perf_counter() - t1
    tt += t

print(tt / 100)
# Out:
# 100%|██████████████████████████████████████████████████████████████| 100/100 [00:56<00:00,  1.75it/s]
# 0.5688167269705445

# %%
segment_features
# Out:
# [({'578,145,698': {'length': 1, 'duration': 1.0, 'speed': 93.0},
#    '578,145,704': {'length': 2,
#     'duration': 1.6666666666666665,
#     'speed': 91.80000000000001},
#    '578,145,710': {'length': 3, 'duration': 2.75, 'speed': 97.45454545454545},
#    '578,145,716': {'length': 4,
#     'duration': 4.666666666666667,
#     'speed': 101.57142857142857},
#    '578,145,722': {'length': 5,
#     'duration': 6.916666666666667,
#     'speed': 103.95180722891565},
#    '578,145,728': {'length': 6,
#     'duration': 8.333333333333334,
#     'speed': 101.39999999999999},
#    '578,145,734': {'length': 7, 'duration': None, 'speed': None},
#    '578,145,740': {'length': 1, 'duration': 0.6666666666666666, 'speed': 90.0},
#    '578,145,746': {'length': 2, 'duration': 1.75, 'speed': 99.42857142857143},
#    '578,145,752': {'length': 3,
#     'duration': 3.666666666666667,
#     'speed': 103.9090909090909},
#    '578,145,758': {'length': 4,
#     'duration': 5.916666666666667,
#     'speed': 105.80281690140845},
#    '578,145,764': {'length': 5,
#     'duration': 7.333333333333334,
#     'speed': 102.54545454545453},
#    '578,145,770': {'length': 6, 'duration': None, 'speed': None},
#    '578,145,776': {'length': 1,
#     'duration': 1.0833333333333333,
#     'speed': 105.23076923076924},
#    '578,145,782': {'length': 2, 'duration': 3.0, 'speed': 107.0},
#    '578,145,788': {'length': 3, 'duration': 5.25, 'speed': 107.80952380952381},
#    '578,145,794': {'length': 4, 'duration': 6.666666666666667, 'speed': 103.8},
#    '578,145,800': {'length': 5, 'duration': None, 'speed': None},
#    '578,145,806': {'length': 1,
#     'duration': 1.9166666666666667,
#     'speed': 108.0},
#    '578,145,812': {'length': 2,
#     'duration': 4.166666666666667,
#     'speed': 108.47999999999999},
#    '578,145,818': {'length': 3,
#     'duration': 5.583333333333334,
#     'speed': 103.52238805970148},
#    '578,145,824': {'length': 4, 'duration': None, 'speed': None},
#    '578,145,830': {'length': 1, 'duration': 2.25, 'speed': 108.88888888888889},
#    '578,145,836': {'length': 2,
#     'duration': 3.666666666666667,
#     'speed': 101.18181818181817},
#    '578,145,842': {'length': 3, 'duration': None, 'speed': None},
#     'duration': 9.166666666666666,
#     'speed': 101.78181818181818},
#    '580,502,054': {'length': 5, 'duration': None, 'speed': None},
#    '580,502,060': {'length': 1, 'duration': 2.5, 'speed': 105.2},
#    '580,502,066': {'length': 2,
#     'duration': 4.916666666666666,
#     'speed': 101.49152542372883},
#    '580,502,072': {'length': 3,
#     'duration': 6.333333333333333,
#     'speed': 98.6842105263158},
#    '580,502,078': {'length': 4, 'duration': None, 'speed': None},
#    '580,502,084': {'length': 1,
#     'duration': 2.4166666666666665,
#     'speed': 97.65517241379311},
#    '580,502,090': {'length': 2,
#     'duration': 3.833333333333333,
#     'speed': 94.43478260869566},
#    '580,502,096': {'length': 3, 'duration': None, 'speed': None},
#    '580,502,102': {'length': 1,
#     'duration': 1.4166666666666667,
#     'speed': 88.94117647058823},
#    '580,502,108': {'length': 2, 'duration': None, 'speed': None},
#    '580,502,114': {'length': 1, 'duration': None, 'speed': None}},
#   0.08068648900371045,
#   4.364599590189755e-05,
#   0.0001259929995285347,
#   9.87399835139513e-06,
#   0.00170224899193272,
#   9.719000081531703e-05,
#   0.001130860997363925,
#   1.823599450290203e-05,
#   3.752700285986066e-05),
#  ({'580,554,590': {'length': 1,
#     'duration': 1.1666666666666667,
#     'speed': 74.57142857142857},
#    '580,554,596': {'length': 2, 'duration': None, 'speed': None},
#    '580,554,602': {'length': 1, 'duration': None, 'speed': None}},
#   0.05097046500304714,
#   3.0177005100995302e-05,
#   2.005300484597683e-05,
#   3.97900294046849e-06,
#   0.0006283140101004392,
#   1.5878002159297466e-05,
#   0.00022203499975148588,
#   2.9619986889883876e-06,
#   1.5830009942874312e-05),
#  ({'580,575,050': {'length': 1, 'duration': 1.0, 'speed': 54.0},
#    '580,575,056': {'length': 2,
#     'duration': 2.083333333333333,
#     'speed': 56.16000000000001},
#    '580,575,062': {'length': 3, 'duration': None, 'speed': None},
#    '580,575,068': {'length': 1,
#     'duration': 1.0833333333333333,
#     'speed': 58.15384615384616},
#    '580,575,074': {'length': 2, 'duration': None, 'speed': None},
#    '580,575,080': {'length': 1, 'duration': None, 'speed': None}},
#   0.06445408701256383,
#   3.178398765157908e-05,
#   5.251499533187598e-05,
#   6.714995834045112e-06,
#   0.0008909309981390834,
#   4.583099507726729e-05,
#   0.0003942180046578869,
#   2.0535007934086025e-05,
#   1.800300378818065e-05),
#  ({'580,581,632': {'length': 1, 'duration': 1.0, 'speed': 54.0},
#    '580,581,638': {'length': 2,
#     'duration': 2.083333333333333,
#     'speed': 56.16000000000001},
#    '580,581,644': {'length': 3, 'duration': None, 'speed': None},
#    '580,581,650': {'length': 1,
#     'duration': 1.0833333333333333,
#     'speed': 58.15384615384616},
#    '580,581,656': {'length': 2, 'duration': None, 'speed': None},
#    '580,581,662': {'length': 1, 'duration': None, 'speed': None}},
#   0.07298979100596625,
#   4.39990108134225e-05,
#   5.3951996960677207e-05,
#   6.0780002968385816e-06,
#   0.0013074759917799383,
#   4.1041988879442215e-05,
#   0.0005015380011172965,
#   9.51999390963465e-06,
#   3.4957993193529546e-05),
#  ({'580,588,916': {'length': 1,
#     'duration': 4.166666666666667,
#     'speed': 112.55999999999999},
#    '580,588,928': {'length': 2, 'duration': None, 'speed': None},
#    '580,588,946': {'length': 1, 'duration': None, 'speed': None}},
#   0.0495693470002152,
#   3.5017001209780574e-05,
#   2.3187007172964513e-05,
#   4.704008460976183e-06,
#   0.0007934110035421327,
#   2.1482002921402454e-05,
#   0.00025126100808847696,
#   2.7520000003278255e-06,
#   1.6353995306417346e-05),
#  ({'674,584,302': {'length': 1, 'duration': None, 'speed': None}},
#   0.06156307000492234,
#   2.321600914001465e-05,
#   2.0202001906000078e-05,
#   3.655004547908902e-06,
#   2.3330067051574588e-06,
#   1.3671000488102436e-05,
#   1.1600059224292636e-06,
#   1.7360143829137087e-06,
#   5.112990038469434e-06),
#  ({'758,276,658': {'length': 1, 'duration': 0.4166666666666667, 'speed': 81.6},
#    '758,276,664': {'length': 2,
#     'duration': 0.5833333333333334,
#     'speed': 73.71428571428571},
#    '758,276,670': {'length': 3, 'duration': None, 'speed': None},
#    '758,276,676': {'length': 1,
#     'duration': 0.16666666666666666,
#     'speed': 54.0},
#    '758,276,682': {'length': 2, 'duration': None, 'speed': None},
#    '758,276,688': {'length': 1, 'duration': None, 'speed': None}},
#   0.06415447600011248,
#   3.0552997486665845e-05,
#   4.126400745008141e-05,
#   6.009009666740894e-06,
#   0.0008780410134932026,
#   3.0342998798005283e-05,
#   0.00039731500146444887,
#   5.697002052329481e-06,
#   3.539900353644043e-05),
#  ({'685,220,160': {'length': 1,
#     'duration': 3.4166666666666665,
#     'speed': 82.53658536585367},
#    '685,220,166': {'length': 2,
#     'duration': 6.416666666666666,
#     'speed': 96.7792207792208},
#    '685,220,172': {'length': 3,
#     'duration': 7.999999999999999,
#     'speed': 98.12500000000001},
#    '685,220,178': {'length': 4,
#     'duration': 10.416666666666666,
#     'speed': 101.47200000000001},
#    '685,220,184': {'length': 5,
#     'duration': 11.416666666666666,
#     'speed': 100.64233576642336},
#    '685,220,190': {'length': 6, 'duration': None, 'speed': None},
#    '685,220,196': {'length': 1, 'duration': 3.0, 'speed': 113.0},
#    '685,220,202': {'length': 2,
#     'duration': 4.583333333333333,
#     'speed': 109.74545454545455},
#    '685,220,208': {'length': 3, 'duration': 7.0, 'speed': 110.71428571428571},
#    '685,220,214': {'length': 4, 'duration': 8.0, 'speed': 108.375},
#    '685,220,220': {'length': 5, 'duration': None, 'speed': None},
#    '685,220,226': {'length': 1,
#     'duration': 1.5833333333333333,
#     'speed': 102.94736842105263},
#    '685,220,232': {'length': 2, 'duration': 4.0, 'speed': 109.0},
#    '685,220,238': {'length': 3, 'duration': 5.0, 'speed': 105.6},
#    '685,220,244': {'length': 4, 'duration': None, 'speed': None},
#    '685,220,250': {'length': 1,
#     'duration': 2.4166666666666665,
#     'speed': 112.55172413793105},
#    '685,220,256': {'length': 2,
#     'duration': 3.4166666666666665,
#     'speed': 106.53658536585367},
#    '685,220,262': {'length': 3, 'duration': None, 'speed': None},
#    '685,220,268': {'length': 1, 'duration': 1.0, 'speed': 92.0},
#    '685,220,274': {'length': 2, 'duration': None, 'speed': None},
#    '685,220,280': {'length': 1, 'duration': None, 'speed': None}},
#   0.0595464039943181,
#   7.656399975530803e-05,
#   0.00011269300011917949,
#   8.351998985745013e-06,
#   0.0019488610123516992,
#   8.68520000949502e-05,
#   0.0010718740086304024,
#   1.4210992958396673e-05,
#   0.00010154000483453274),
#  ({'653,658,282': {'length': 1, 'duration': None, 'speed': None}},
#   0.03958074899856001,
#   3.1917006708681583e-05,
#   2.2061998606659472e-05,
#   3.335997462272644e-06,
#   2.8260110411792994e-06,
#   1.9558006897568703e-05,
#   2.2940075723454356e-06,
#   1.3850076356902719e-06,
#   6.400994607247412e-06),
#  ({'580,967,648': {'length': 1, 'duration': None, 'speed': None}},
#   0.03647990900208242,
#   2.8130001737736166e-05,
#   2.0767998648807406e-05,
#   3.905995981767774e-06,
#   1.5190016711130738e-06,
#   1.897200127132237e-05,
#   9.399955160915852e-07,
#   2.578992280177772e-06,
#   7.081995136104524e-06),
#  ({'580,984,094': {'length': 1, 'duration': None, 'speed': None}},
#   0.03767577600956429,
#   2.8333990485407412e-05,
#   2.444999699946493e-05,
#   3.7809950299561024e-06,
#   2.172004315070808e-06,
#   1.403699570801109e-05,
#   1.7870042938739061e-06,
#   2.401997335255146e-06,
#   6.157002644613385e-06),
#  ({'745,431,096': {'length': 1, 'duration': None, 'speed': None}},
#   0.04662669499521144,
#   2.6644003810361028e-05,
#   1.978799991775304e-05,
#   4.3470063246786594e-06,
#   2.4089968064799905e-06,
#   1.4935998478904366e-05,
#   1.00000761449337e-06,
#   2.397995558567345e-06,
#   5.331996362656355e-06),
#  ({'581,081,552': {'length': 1, 'duration': 0.25, 'speed': 48.0},
#    '581,081,558': {'length': 2,
#     'duration': 0.5833333333333333,
#     'speed': 61.71428571428572},
#    '581,081,564': {'length': 3,
#     'duration': 1.1666666666666665,
#     'speed': 63.42857142857144},
#    '581,081,570': {'length': 4,
#     'duration': 1.6666666666666665,
#     'speed': 63.60000000000001},
#    '581,081,576': {'length': 5, 'duration': None, 'speed': None},
#    '581,081,582': {'length': 1, 'duration': 0.3333333333333333, 'speed': 72.0},
#    '581,081,588': {'length': 2,
#     'duration': 0.9166666666666667,
#     'speed': 67.63636363636363},
#    '581,081,594': {'length': 3,
#     'duration': 1.4166666666666667,
#     'speed': 66.35294117647058},
#    '581,081,600': {'length': 4, 'duration': None, 'speed': None},
#    '581,081,606': {'length': 1,
#     'duration': 0.5833333333333334,
#     'speed': 65.14285714285714},
#    '581,081,612': {'length': 2,
#     'duration': 1.0833333333333335,
#     'speed': 64.61538461538461},
#    '581,081,618': {'length': 3, 'duration': None, 'speed': None},
#    '581,081,624': {'length': 1, 'duration': 0.5, 'speed': 64.0},
#    '581,081,630': {'length': 2, 'duration': None, 'speed': None},
#    '581,081,636': {'length': 1, 'duration': None, 'speed': None}},
#   0.04582416899211239,
#   4.1310995584353805e-05,
#   8.335898746736348e-05,
#   3.016000846400857e-06,
#   5.497000529430807e-06),
#  ({'824,841,000': {'length': 1, 'duration': 0.75, 'speed': 101.33333333333333},
#    '824,841,006': {'length': 2, 'duration': 1.25, 'speed': 88.0},
#    '824,841,012': {'length': 3, 'duration': 2.0, 'speed': 79.0},
#    '824,841,018': {'length': 4,
#     'duration': 2.1666666666666665,
#     'speed': 78.92307692307693},
#    '824,841,024': {'length': 5,
#     'duration': 2.4166666666666665,
#     'speed': 77.37931034482759},
#    '824,841,030': {'length': 6, 'duration': None, 'speed': None},
#    '824,841,036': {'length': 1, 'duration': 0.5, 'speed': 68.0},
#    '824,841,042': {'length': 2, 'duration': 1.25, 'speed': 65.6},
#    '824,841,048': {'length': 3,
#     'duration': 1.4166666666666667,
#     'speed': 67.05882352941177},
#    '824,841,054': {'length': 4, 'duration': 1.6666666666666667, 'speed': 66.0},
#    '824,841,060': {'length': 5, 'duration': None, 'speed': None},
#    '824,841,066': {'length': 1, 'duration': 0.75, 'speed': 64.0},
#    '824,841,072': {'length': 2,
#     'duration': 0.9166666666666666,
#     'speed': 66.54545454545455},
#    '824,841,078': {'length': 3,
#     'duration': 1.1666666666666665,
#     'speed': 65.14285714285715},
#    '824,841,090': {'length': 4, 'duration': None, 'speed': None},
#    '824,841,096': {'length': 1,
#     'duration': 0.16666666666666666,
#     'speed': 78.0},
#    '824,841,102': {'length': 2,
#     'duration': 0.41666666666666663,
#     'speed': 69.60000000000001},
#    '824,841,108': {'length': 3, 'duration': None, 'speed': None},
#    '824,841,114': {'length': 1, 'duration': 0.25, 'speed': 64.0},
#    '824,841,120': {'length': 2, 'duration': None, 'speed': None},
#    '824,841,126': {'length': 1, 'duration': None, 'speed': None}},
#   0.05180112100788392,
#   5.310600681696087e-05,
#   0.0001546889980090782,
#   1.1846001143567264e-05,
#   0.003935475993785076,
#   0.00017042699619196355,
#   0.0015606480010319501,
#   2.130000211764127e-05,
#   4.344500484876335e-05),
#  ({'920,901,012': {'length': 1, 'duration': 2.0, 'speed': 64.0},
#    '920,901,018': {'length': 2, 'duration': 6.25, 'speed': 64.64},
#    '920,901,030': {'length': 3,
#     'duration': 8.333333333333334,
#     'speed': 64.67999999999999},
#    '920,901,036': {'length': 4,
#     'duration': 10.833333333333334,
#     'speed': 62.86153846153846},
#    '920,901,042': {'length': 5, 'duration': 16.25, 'speed': 60.61538461538461},
#    '920,901,048': {'length': 6, 'duration': None, 'speed': None},
#    '920,901,054': {'length': 1, 'duration': 4.25, 'speed': 64.94117647058823},
#    '920,901,060': {'length': 2,
#     'duration': 6.333333333333334,
#     'speed': 64.89473684210526},
#    '920,901,066': {'length': 3,
#     'duration': 8.833333333333334,
#     'speed': 62.60377358490565},
#    '920,901,072': {'length': 4, 'duration': 14.25, 'speed': 60.21052631578947},
#    '920,901,078': {'length': 5, 'duration': None, 'speed': None},
#    '920,901,084': {'length': 1, 'duration': 2.0833333333333335, 'speed': 64.8},
#    '920,901,090': {'length': 2,
#     'duration': 4.583333333333334,
#  ({'585,972,356': {'length': 1,
#     'duration': 1.1666666666666667,
#     'speed': 74.57142857142857},
#    '585,972,362': {'length': 2,
#     'duration': 5.166666666666667,
#     'speed': 106.06451612903226},
#    '585,972,368': {'length': 3, 'duration': None, 'speed': None},
#    '585,972,374': {'length': 1, 'duration': 4.0, 'speed': 115.25},
#    '585,972,380': {'length': 2, 'duration': None, 'speed': None},
#    '585,972,386': {'length': 1, 'duration': None, 'speed': None}},
#   0.04307248200348113,
#   2.7870002668350935e-05,
#   4.084099782630801e-05,
#   6.040994776412845e-06,
#   0.0008027729927562177,
#   2.5865010684356093e-05,
#   0.0003384890005690977,
#   5.438996595330536e-06,
#   1.2443997547961771e-05),
#  ({'585,983,612': {'length': 1, 'duration': None, 'speed': None}},
#   0.026416931999847293,
#   1.824999344535172e-05,
#   1.662199792917818e-05,
#   3.107998054474592e-06,
#   1.7830025171861053e-06,
#   1.119299849960953e-05,
#   9.790092008188367e-07,
#   1.4289980754256248e-06,
#   3.4520053304731846e-06),
#  ({'790,374,300': {'length': 1,
#     'duration': 1.9166666666666667,
#     'speed': 113.21739130434783},
#    '790,374,306': {'length': 2, 'duration': None, 'speed': None},
#    '790,374,312': {'length': 1, 'duration': None, 'speed': None}},
#   0.020892385000479408,
#   1.6403995687142015e-05,
#   2.1195010049268603e-05,
#   3.7629943108186126e-06,
#   0.0003721819957718253,
#   1.6510006389580667e-05,
#   0.00018186299712397158,
#   2.986998879350722e-06,
#   4.993999027647078e-06),
#  ({'586,316,642': {'length': 1, 'duration': 1.6666666666666667, 'speed': 63.0},
#    '586,316,648': {'length': 2,
#     'duration': 2.5833333333333335,
#     'speed': 71.2258064516129},
#    '586,316,654': {'length': 3, 'duration': 3.5, 'speed': 75.42857142857143},
#    '586,316,660': {'length': 4, 'duration': None, 'speed': None},
#    '586,316,666': {'length': 1,
#     'duration': 0.9166666666666666,
#     'speed': 85.0909090909091},
#    '586,316,672': {'length': 2,
#     'duration': 1.8333333333333333,
#     'speed': 86.72727272727273},
#    '586,316,678': {'length': 3, 'duration': None, 'speed': None},
#    '586,316,684': {'length': 1,
#     'duration': 0.9166666666666666,
#     'speed': 87.27272727272728},
#    '586,316,690': {'length': 2, 'duration': None, 'speed': None},
#    '586,316,696': {'length': 1, 'duration': None, 'speed': None}},
#   0.04378289700252935,
#   2.6516005164012313e-05,
#   5.6069999118335545e-05,
#   5.895999493077397e-06,
#   0.0009106369980145246,
#   4.173499473836273e-05,
#   0.0009196350001730025,
#   8.048999006859958e-06,
#   2.163200406357646e-05)]

# %%
ms["segment_datetime"] = pd.to_datetime(ms["segment_datetime"])
ms["published_date"] = pd.to_datetime(ms["published_date"])
ms["signup_date"] = pd.to_datetime(ms["signup_date"])

# %%
ms["hours_before_start"] = (ms["segment_datetime"] - ms["published_date"]).apply(lambda x: x.seconds/3600)

# %%
ms["days_since_signup"] = (ms["published_date"] - ms["signup_date"]).apply(lambda x: x.days)

# %%
one_hot = pd.get_dummies(ms["fixed_signup_country"])
ms.drop("fixed_signup_country", axis=1, inplace=True)
ms = ms.join(one_hot)

one_hot = pd.get_dummies(ms["publication_site_id"])
ms.drop("publication_site_id", axis=1, inplace=True)
ms = ms.join(one_hot)

# %%
import numpy as np

from sklearn.cluster import MiniBatchKMeans

coords = np.vstack((ms[['from_lat', 'from_lon']].values,
                    ms[['to_lat', 'to_lon']].values))

sample_ind = np.random.permutation(len(coords))
kmeans = MiniBatchKMeans(n_clusters=100, batch_size=10000).fit(coords[sample_ind])

ms.loc[:, 'from_cluster'] = kmeans.predict(ms[['from_lat', 'from_lon']].values)
ms.loc[:, 'to_cluster'] = kmeans.predict(ms[['to_lat', 'to_lon']].values)

# %%
min(ms["segment_datetime"]), max(ms["segment_datetime"])
# Out:
# (Timestamp('2015-04-15 00:00:00'), Timestamp('2015-10-12 22:50:00'))

# %%
cluster_in_counts = dict(ms["to_cluster"].value_counts())
cluster_out_counts = dict(ms["from_cluster"].value_counts())

# %%
ms["from_cluster_in_count"] = ms["from_cluster"].apply(lambda x: cluster_in_counts[x]) / len(ms)
ms["from_cluster_out_count"] = ms["from_cluster"].apply(lambda x: cluster_out_counts[x]) / len(ms)
ms["to_cluster_in_count"] = ms["to_cluster"].apply(lambda x: cluster_in_counts[x]) / len(ms)
ms["to_cluster_out_count"] = ms["to_cluster"].apply(lambda x: cluster_out_counts[x]) / len(ms)

# %%
def haversine_array(lat1, lng1, lat2, lng2):
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2))
    AVG_EARTH_RADIUS = 6371  # in km
    lat = lat2 - lat1
    lng = lng2 - lng1
    d = np.sin(lat * 0.5) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(lng * 0.5) ** 2
    h = 2 * AVG_EARTH_RADIUS * np.arcsin(np.sqrt(d))
    return h

# %%
ms["unit_seat_price_eur"] = ms["unit_seat_price_eur"].apply(lambda x: float(x.replace(",", "")))
ms["segment_distance_km"] = ms["segment_distance_km"].apply(lambda x: float(x.replace(",", "")))

# %%
ms["haversine_distance"] = haversine_array(ms["from_lat"], ms["from_lon"], ms["to_lat"], ms["to_lon"])
ms["over_lenghtification"] = ms["segment_distance_km"] / ms["haversine_distance"]

# %% [markdown]
# ### Datetime Features

# %%
ms.loc[:, 'pickup_weekday'] = ms['segment_datetime'].dt.weekday
ms.loc[:, 'pickup_hour_weekofyear'] = ms['segment_datetime'].dt.weekofyear
ms.loc[:, 'pickup_hour'] = ms['segment_datetime'].dt.hour
ms.loc[:, 'pickup_minute'] = ms['segment_datetime'].dt.minute
ms.loc[:, 'pickup_dt'] = (ms['segment_datetime'] - ms['segment_datetime'].min()).dt.total_seconds()
ms.loc[:, 'pickup_week_hour'] = ms['pickup_weekday'] * 24 + ms['pickup_hour']
# Out:
# /home/issa/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
ms.loc[:, "target"] = (ms["seat_offered_count"] > ms["seat_left_count"]).astype(int)

# %%
ms.drop(["driver_id", "trip_id", "segment_id", "confirmed_seat_count", "seat_left_count"], inplace=True, axis=1)

# %%
ms.drop(["is_main_segment", "segment_datetime", "published_date", "signup_date"], inplace=True, axis=1)

# %%
ms["target"].value_counts()
# Out:
# 1    1693951
# 0    1685827
# Name: target, dtype: int64

# %%
ms = ms[~ms.isin([np.nan, np.inf, -np.inf]).any(1)]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(ms, test_size=0.2)

# %%
X_train, Y_train = train.values[:, :-1], train.values[:, -1]
X_test, Y_test = test.values[:, :-1], test.values[:, -1]

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    eval_metric="logloss",
    use_label_encoder=False,
    n_estimators=10
)
model.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='logloss', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=10, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test.astype(float), Y_pred.astype(float)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.63      0.64    336894
#          1.0       0.65      0.67      0.66    339049
#
#     accuracy                           0.65    675943
#    macro avg       0.65      0.65      0.65    675943
# weighted avg       0.65      0.65      0.65    675943

# %%
pd.DataFrame(zip(train.columns[:-1], model.feature_importances_)).set_index(0).sort_values(by=1, ascending=False).plot.bar(figsize=(12, 8))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_30962/1017658775.py in <module>
# ----> 1 pd.DataFrame(zip(train.columns[:-1], model.feature_importances_)).set_index(0).sort_values(by=1, ascending=False).plot.bar(figsize=(12, 8))
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     890
#     891     def __call__(self, *args, **kwargs):
# --> 892         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     893
#     894         x, y, kind, kwargs = self._get_call_args(
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1812         return _backends[backend]
#    1813
# -> 1814     module = _load_backend(backend)
#    1815     _backends[backend] = module
#    1816     return module
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/pandas/plotting/_core.py in _load_backend(backend)
#    1750         # we need to attempt an import here to raise an ImportError if needed.
#    1751         try:
# -> 1752             module = importlib.import_module("pandas.plotting._matplotlib")
#    1753         except ImportError:
#    1754             raise ImportError(
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in <module>
#       3 from typing import TYPE_CHECKING
#       4
# ----> 5 from pandas.plotting._matplotlib.boxplot import (
#       6     BoxPlot,
#       7     boxplot,
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/pandas/plotting/_matplotlib/boxplot.py in <module>
#       5 import warnings
#       6
# ----> 7 from matplotlib.artist import setp
#       8 import numpy as np
#       9
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/matplotlib/__init__.py in <module>
#     105 # cbook must import matplotlib only within function
#     106 # definitions, so it is safe to import from it here.
# --> 107 from . import _api, cbook, docstring, rcsetup
#     108 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
#     109 from matplotlib.cbook import mplDeprecation  # deprecated
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/matplotlib/rcsetup.py in <module>
#      24 from matplotlib import _api, animation, cbook
#      25 from matplotlib.cbook import ls_mapper
# ---> 26 from matplotlib.colors import Colormap, is_color_like
#      27 from matplotlib.fontconfig_pattern import parse_fontconfig_pattern
#      28 from matplotlib._enums import JoinStyle, CapStyle
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/matplotlib/colors.py in <module>
#      76 import re
#      77 from PIL import Image
# ---> 78 from PIL.PngImagePlugin import PngInfo
#      79
#      80 import matplotlib as mpl
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/site-packages/PIL/PngImagePlugin.py in <module>
#      39 import zlib
#      40
# ---> 41 from . import Image, ImageChops, ImageFile, ImagePalette, ImageSequence
#      42 from ._binary import i16be as i16
#      43 from ._binary import i32be as i32
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# ~/.pyenv/versions/3.7.4/envs/blablacar/lib/python3.7/importlib/_bootstrap_external.py in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt

points = set(froms + tos)
x = []
y = []
for p in points:
    x.append(p[0])
    y.append(p[1])

plt.figure(figsize=(12, 8), dpi=80)
plt.scatter(x, y, s=0.1)
plt.show()

# %%
ms
